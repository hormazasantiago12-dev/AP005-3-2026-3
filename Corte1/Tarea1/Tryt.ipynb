# %% [markdown]
# ```markdown
# Este bloque de código define una variable llamada `my_cool_variable` y le asigna el resultado de la comparación lógica `7 + 8 == 11`. Luego, imprime el valor de esta variable en la consola.
# ```

# %%
my_cool_variable = 7 + 8 == 11
print(my_cool_variable)
