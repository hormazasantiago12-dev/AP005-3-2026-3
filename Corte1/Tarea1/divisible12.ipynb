# %% [markdown]
# Este código itera a través de números del 100 al 300 (inclusive). Para cada número, verifica si es divisible por 12. Si no lo es, salta al siguiente número. Si es divisible por 12, imprime el número.

# %%
for i in range(100, 301):
    if (i%12) != 0:
        continue
    print(i)
# Out:
# 108
# 120
# 132
# 144
# 156
# 168
# 180
# 192
# 204
# 216
# 228
# 240
# 252
# 264
# 276
# 288
# 300
